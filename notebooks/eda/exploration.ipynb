# %%
import pandas as pd

# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

meta = getDF('../Data/meta_Grocery_and_Gourmet_Food.json.gz')

# %%
df = getDF('../Data/Grocery_and_Gourmet_Food.json.gz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7e5c44c2145e> in <module>
# ----> 1 df = getDF('../Data/Grocery_and_Gourmet_Food.json.gz')
#
# <ipython-input-12-b9de82b0d71c> in getDF(path)
#      10   i = 0
#      11   df = {}
# ---> 12   for d in parse(path):
#      13     df[i] = d
#      14     i += 1
#
# <ipython-input-12-b9de82b0d71c> in parse(path)
#       5   g = gzip.open(path, 'rb')
#       6   for l in g:
# ----> 7     yield eval(l)
#       8
#       9 def getDF(path):
#
# <string> in <module>
#
# NameError: name 'true' is not defined

# %%
meta.head()
# Out:
#                                             category tech1  \
# 0  [Grocery & Gourmet Food, Dairy, Cheese & Eggs,...
# 1  [Grocery & Gourmet Food, Cooking & Baking, Sug...
# 2  [Grocery & Gourmet Food, Cooking & Baking, Fro...
# 3  [Grocery & Gourmet Food, Cooking & Baking, Fro...
# 4  [Grocery & Gourmet Food, Cooking & Baking, Fro...
#
#                                          description fit  \
# 0  [BEEMSTER GOUDA CHEESE AGED 18/24 MONTHS, Stat...
# 1  [Shipped from UK, please allow 10 to 21 busine...
# 2  [Jazz up your cakes with a sparkling monogram ...
# 3                      [Large Letter - Height 4.75"]
# 4                                            [4.75"]
#
#                                                title  \
# 0  Beemster Gouda - Aged 18/24 Months - App. 1.5 Lbs
# 1                          Trim Healthy Mama Xylitol
# 2  Letter C - Swarovski Crystal Monogram Wedding ...
# 3  Letter H - Swarovski Crystal Monogram Wedding ...
# ...

# %%
meta[meta['main_cat']=='Grocery']
# Out:
#                                                  category tech1  \
# 0       [Grocery & Gourmet Food, Dairy, Cheese & Eggs,...
# 1       [Grocery & Gourmet Food, Cooking & Baking, Sug...
# 10      [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 11      [Grocery & Gourmet Food, Beverages, Coffee, Te...
# 12      [Grocery & Gourmet Food, Beverages, Coffee, Te...
# ...                                                   ...   ...
# 287046  [Grocery & Gourmet Food, Jams, Jellies & Sweet...
# 287047  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 287048  [Grocery & Gourmet Food, Condiments & Salad Dr...
# 287049  [Grocery & Gourmet Food, Herbs, Spices & Seaso...
# 287050  [Grocery & Gourmet Food, Beverages, Bottled Be...
#
#                                               description fit  \
# 0       [BEEMSTER GOUDA CHEESE AGED 18/24 MONTHS, Stat...
# 1       [Shipped from UK, please allow 10 to 21 busine...
# 10      [Lipton Yellow Label Tea use only the finest t...
# ...

# %%
meta['main_cat'].unique()
# Out:
# array(['Grocery', 'Amazon Home', 'Health & Personal Care', 'All Beauty',
#        'Toys & Games', 'Sports & Outdoors', 'Industrial & Scientific',
#        'Arts, Crafts & Sewing', 'Home Audio & Theater', 'Pet Supplies',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/digital/music/logos/amzn_music_logo_subnav._CB471835632_.png" class="nav-categ-image" alt="Digital Music"/>',
#        'Office Products', 'Cell Phones & Accessories', 'Movies & TV',
#        'Portable Audio & Accessories', 'Baby', 'Tools & Home Improvement',
#        'Computers', 'Automotive',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/nav2/images/gui/amazon-fashion-store-new._CB520838675_.png" class="nav-categ-image" alt="AMAZON FASHION"/>',
#        '<img src="https://images-na.ssl-images-amazon.com/images/G/01/pantry/subnav/pantry-subnav-logo._CB474181323_.png" class="nav-categ-image" alt="Prime Pantry"/>',
#        'All Electronics', 'Software', '',
# ...

# %%
df = pd.read_csv('../Data/sg_store_rev.csv')
df.head()
# Out:
#                                  hustle-co-singapore  \
# 0  I would say that I accidentally discovered thi...
# 1  Get away from the hustle 'n' bustle!This funky...
# 2  Got their Dirty Burger (medium) & Red Apple Ci...
# 3  Got their Dirty Burger (medium) & Red Apple Ci...
# 4  Salmon Rosti and French toast were delish! I w...
#
#                       benjamin-barker-cafe-singapore  \
# 0  Nice cafe near Orchard Road. We had the Egg Be...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                       the-coffee-roaster-singapore-2  \
# 0  A refreshing place with a quiet ambience and n...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df = pd.read_csv('../Data/sg_store_userid.csv')
df.head()
# Out:
#       hustle-co-singapore benjamin-barker-cafe-singapore  \
# 0  DY6s438vFKfblXEWxG0S1g         qPMX0LylFc65ZXkivCRPsQ
# 1  YziRZOh5MrqN5b84dQ9AIQ                            NaN
# 2  21uYcVHQ8uf9GIKrahY2VA                            NaN
# 3  oUZ3fmICiFLVrUBl0lDx4g                            NaN
# 4                     NaN                            NaN
#
#   the-coffee-roaster-singapore-2      koi-cafe-singapore  \
# 0         pDk2mjq7RTpIc6AWIvrbfw  FQZZsU3J88IGF8n5e3XYZg
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
#
#    starbucks-singapore-21 eaglewings-loft-singapore  \
# 0            1Q2GYf4LGZiJ    cCZpMsB_EXkMyn_OvQbdEA
# 1  Vc5DGfRMkBs8Gyibr47LRg    2F38Uc4UNNbFVdyUUnBjOA
# 2  GbcYr_XnbaiYAuFcgHZcbQ                       NaN
# 3  rJpsaqiXNcwoKwvRz0a1rg                       NaN
# ...

# %%
df = pd.read_csv('../Data/shop_rating_userid.csv', names=['shop','rating','user_id'])
df.head()
# Out:
#                   shop  rating  user_id
# 0  hustle-co-singapore     5.0      532
# 1  hustle-co-singapore     5.0     1397
# 2  hustle-co-singapore     5.0       80
# 3  hustle-co-singapore     5.0     2073
# 4  hustle-co-singapore     5.0     2043

# %%
df[df['user_id']==5]
# Out:
#                                  shop  rating  user_id
# 192            toms-palette-singapore     5.0        5
# 1429           wild-honey-singapore-3     4.0        5
# 2784  il-pomeriggio-da-cova-singapore     5.0        5
# 2863           starbucks-singapore-29     5.0        5
# 5202    mr-teh-tarik-cartel-singapore     5.0        5
# 6490              twg-tea-singapore-3     5.0        5

# %%
len(df.user_id.unique())
# Out:
# 2552

# %%
len(df.shop.unique())
# Out:
# 981

# %%
1 - len(df) / (len(df.shop.unique()) * len(df.user_id.unique()))
# Out:
# 0.997173570568066

# %%
df[df['user_id']==2043]
# Out:
#                                 shop  rating  user_id
# 4                hustle-co-singapore     5.0     2043
# 6     benjamin-barker-cafe-singapore     4.0     2043
# 8     the-coffee-roaster-singapore-2     3.0     2043
# 10                koi-cafe-singapore     5.0     2043
# 16            starbucks-singapore-21     4.0     2043
# ...                              ...     ...      ...
# 7064       smoothy-de-cafe-singapore     4.0     2043
# 7066    lee-siau-ling-cafe-singapore     5.0     2043
# 7069             moly-cafe-singapore     5.0     2043
# 7073             artease-singapore-2     4.0     2043
# 7075          starbucks-singapore-52     3.0     2043
#
# [980 rows x 3 columns]

# %%
counts = df['user_id'].value_counts(sort=True)
# counts = counts[counts >= 5]
counts
# Out:
# 2043    980
# 306      65
# 91       64
# 186      52
# 2061     52
#        ...
# 937       1
# 933       1
# 929       1
# 925       1
# 2         1
# Name: user_id, Length: 2552, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

counts = df['user_id'].value_counts(sort=True)
# counts = counts[counts >= 5]
counts = counts[counts < 980]
counts

counts.index = counts.index.map(str)
p = counts.plot.line(color='black')
p.axes.get_xaxis().set_ticks([])
p.set_xlabel('User ID')
p.set_ylabel('Number of Reviews')
plt.fill_between(counts.index, counts, where=counts >= 5, alpha=0.4)
plt.fill_between(counts.index, counts, where=counts < 5, alpha=0.4)
plt.axvline(x=sum(counts >= 5), linestyle='--', color='red')
plt.legend(handles=[mpatches.Patch(color='#1f77b4', alpha=0.4, label='>= 5 reviews'),
                    mpatches.Patch(color='#ff7f0e', alpha=0.4, label='< 5 reviews')],
           loc="upper right", framealpha=0.1)
plt.title('Distribution of Reviews Per User', size=20)
# plt.savefig('../Plots/long_tail.pdf', transparent=True)
plt.savefig('../Plots/long_tail.png', transparent=True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(a, bins=50)
# Out:
# (array([2.526e+03, 1.900e+01, 4.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  1.  ,  20.58,  40.16,  59.74,  79.32,  98.9 , 118.48, 138.06,
#         157.64, 177.22, 196.8 , 216.38, 235.96, 255.54, 275.12, 294.7 ,
#         314.28, 333.86, 353.44, 373.02, 392.6 , 412.18, 431.76, 451.34,
#         470.92, 490.5 , 510.08, 529.66, 549.24, 568.82, 588.4 , 607.98,
# ...

# %%
a = list(df['532'].value_counts())

# %%
df['532'].value_counts().value_counts()
# Out:
# 1      1713
# 2       375
# 3       122
# 4        83
# 5        50
# 6        31
# 9        24
# 7        24
# 8        20
# 10       17
# 13       12
# 11       12
# 16       10
# 12        9
# 15        7
# 14        6
# 17        4
# 19        4
# 32        3
# 26        3
# 24        3
# 20        3
# 23        2
# 52        2
# 25        2
# 21        1
# 29        1
# 47        1
# 27        1
# 980       1
# 64        1
# 50        1
# 36        1
# 28        1
# 22        1
# 65        1
# Name: 532, dtype: int64
