# %%
import numpy as np 
import pandas as pd 

import requests
import urllib
import random
import time
from bs4 import BeautifulSoup as bs
import re
import json

# %% [markdown]
# ### Using Yelp API for scraping coffee-related shops

# %%
api_key = '' # your yelp api key

# %%
# API constants, you shouldn't have to change these.
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  # Business ID will come after slash.

# %%
end_point = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'bearer %s' % api_key}

# %%
# coffee_places_sg = []
# for i in range(50):
#    parameters_sg = {'term':'boba',
#                  'limit':50,
#                  'radius':10000,
#                  'offset':i*50,
#                  'location':'Singapore'}

#    response_sg = requests.get(url=end_point,params=parameters_sg,headers=headers)
#    business_search_sg = response_sg.json()
    
#    try:
#        [biz for biz in business_search_sg['businesses']] 
#    except:
#        print("no more businesses to be scraped!")
#        break
#    coffee_places_sg.extend([biz for biz in business_search_sg['businesses']])
#    print("{} sg coffee places scraped!".format(len(coffee_places_sg)))
#    sleep_duration = random.randint(120,240)
#    print('Break for {} seconds'.format(sleep_duration))
#    time.sleep(sleep_duration)
    
# df = pd.DataFrame(coffee_places_sg)

# %%
# df.to_csv('sg_boba_shops.csv', index=False)

# %% [markdown]
# ### Using beautiful soup to scrape the userid, ratings, text reviews, date etc

# %%
# select idx of coffee shops to scrape
START_IDX = 0
END_IDX = 100

# %%
df = pd.read_csv('../input/coffeeshops/sg_coffee_shops.csv')
aliases_sg = df['alias']
aliases_sg = aliases_sg[START_IDX:END_IDX]

# %%
aliases_sg = pd.read_csv('../input/coffeeshops/shops_norating2.csv')['shop'].values[START_IDX:END_IDX]

# %%
all_data = pd.DataFrame()
outlet_count = 0
count_increment = 10 # each page can have max 10 ratings/reviews
for alias in aliases_sg:
    count = 0
    
    while True:
        sg_url = "https://www.yelp.com/biz/{}?osq=coffee".format(alias) + "&start=" + str(count)
        print(sg_url)
        sg_store = requests.get(sg_url)
        sg_store_soup = bs(sg_store.content, 'lxml')
        
        # get users from tags in page; tag is in this format (<a class="css-1m051bw" href="/user_details?userid=9YLROKnskYk3OVZosiwC7A" role="link">John D.</a>)
        users = [(tag.attrs.get('href').replace('/user_details?userid=', ''), tag.contents[0]) \
                for tag in sg_store_soup.find_all('a',{'class':'css-1m051bw'}) \
                if tag.attrs.get('role') and 'user_details' in tag.attrs.get('href')]

        if not users:
            print(alias, "no reviews")
            outlet_count += 1
            print("{} stores out of {} stores done!".format(outlet_count,len(aliases_sg)))
            sleep_duration = random.randint(30,50)
            print("Resting {} seconds...".format(sleep_duration))
            print(" ")
            time.sleep(sleep_duration)
            break
            
        else:
            users = pd.DataFrame(users)
            users.columns = ['userid', 'author']
            
            # Create dictionary from script
            script = sg_store_soup.find_all('script',{'type':'application/json'})[0].contents[0]
            jsonStr = re.search(r'\{.*\}', str(script)).group()
            dct = json.loads(jsonStr)
            
            # extract review (userid, ratings, text etc) info from dict
            reviews = pd.DataFrame(dct['legacyProps']['bizDetailsProps']['bizDetailsPageProps']['reviewFeedQueryProps']['reviews'])
            reviews = reviews[['business', 'userId', 'user', 'rating', 'localizedDate', 'comment', 'photos']]
            reviews['business'] = reviews['business'].apply(lambda x: x['alias'])
            reviews['username'] = reviews['user'].apply(lambda x: x['markupDisplayName'])
            reviews['language'] = reviews['comment'].apply(lambda x: x['language'])
            reviews['text'] = reviews['comment'].apply(lambda x: x['text'])
            reviews.drop('comment', inplace=True, axis=1)
            reviews.columns = ['shop', 'userid', 'userinfo', 'rating', 'date', 'photos', 'username', 'language', 'text']
            
            all_data = pd.concat([all_data, reviews], axis=0)
            all_data.to_csv('sg_UIRRD.csv', index=False)
            
            count += count_increment
# Out:
# https://www.yelp.com/biz/tcc-the-connoisseur-concerto-singapore-13?osq=coffee&start=0
# tcc-the-connoisseur-concerto-singapore-13 no reviews
# 1 stores out of 15 stores done!
# Resting 31 seconds...
#
# https://www.yelp.com/biz/cafe-nido-singapore?osq=coffee&start=0
# cafe-nido-singapore no reviews
# 2 stores out of 15 stores done!
# Resting 34 seconds...
#
# https://www.yelp.com/biz/killiney-kopitiam-singapore-11?osq=coffee&start=0
# https://www.yelp.com/biz/killiney-kopitiam-singapore-11?osq=coffee&start=10
# killiney-kopitiam-singapore-11 no reviews
# 3 stores out of 15 stores done!
# Resting 44 seconds...
#
# https://www.yelp.com/biz/chocolate-mark-singapore?osq=coffee&start=0
# chocolate-mark-singapore no reviews
# 4 stores out of 15 stores done!
# Resting 30 seconds...
#
# https://www.yelp.com/biz/starbucks-singapore-129?osq=coffee&start=0
# https://www.yelp.com/biz/starbucks-singapore-129?osq=coffee&start=10
# starbucks-singapore-129 no reviews
# 5 stores out of 15 stores done!
# Resting 46 seconds...
#
# https://www.yelp.com/biz/the-coffee-bean-and-tea-leaf-singapore-9?osq=coffee&start=0
# https://www.yelp.com/biz/the-coffee-bean-and-tea-leaf-singapore-9?osq=coffee&start=10
# the-coffee-bean-and-tea-leaf-singapore-9 no reviews
# 6 stores out of 15 stores done!
# Resting 33 seconds...
#
# https://www.yelp.com/biz/cafe-del-mar-sentosa-singapore?osq=coffee&start=0
# cafe-del-mar-sentosa-singapore no reviews
# 7 stores out of 15 stores done!
# Resting 38 seconds...
#
# https://www.yelp.com/biz/second-storey-cafe-bar-singapore?osq=coffee&start=0
# https://www.yelp.com/biz/second-storey-cafe-bar-singapore?osq=coffee&start=10
# second-storey-cafe-bar-singapore no reviews
# 8 stores out of 15 stores done!
# Resting 36 seconds...
#
# https://www.yelp.com/biz/earlybird-singapore?osq=coffee&start=0
# earlybird-singapore no reviews
# 9 stores out of 15 stores done!
# Resting 33 seconds...
#
# https://www.yelp.com/biz/old-school-delights-singapore-4?osq=coffee&start=0
# old-school-delights-singapore-4 no reviews
# 10 stores out of 15 stores done!
# Resting 37 seconds...
#
# https://www.yelp.com/biz/starbucks-singapore-118?osq=coffee&start=0
# https://www.yelp.com/biz/starbucks-singapore-118?osq=coffee&start=10
# starbucks-singapore-118 no reviews
# 11 stores out of 15 stores done!
# Resting 43 seconds...
#
# https://www.yelp.com/biz/hg-106-coffeeshop-singapore?osq=coffee&start=0
# https://www.yelp.com/biz/hg-106-coffeeshop-singapore?osq=coffee&start=10
# hg-106-coffeeshop-singapore no reviews
# 12 stores out of 15 stores done!
# Resting 33 seconds...
#
# https://www.yelp.com/biz/starbucks-singapore-106?osq=coffee&start=0
# https://www.yelp.com/biz/starbucks-singapore-106?osq=coffee&start=10
# starbucks-singapore-106 no reviews
# 13 stores out of 15 stores done!
# Resting 50 seconds...
#
# https://www.yelp.com/biz/xinspa-spaworks-singapore?osq=coffee&start=0
# xinspa-spaworks-singapore no reviews
# 14 stores out of 15 stores done!
# Resting 42 seconds...
#
# https://www.yelp.com/biz/jin-wee-coffee-shop-singapore?osq=coffee&start=0
# https://www.yelp.com/biz/jin-wee-coffee-shop-singapore?osq=coffee&start=10
# jin-wee-coffee-shop-singapore no reviews
# 15 stores out of 15 stores done!
# Resting 49 seconds...

# %%
all_data
# Out:
#                                        shop                  userid  \
# 0            killiney-kopitiam-singapore-11  EIwNqeBDMQ4Q6k0DQ30SyA
# 1            killiney-kopitiam-singapore-11  _I4S9ZWAoJ2PDippwT605g
# 2            killiney-kopitiam-singapore-11  VxwCgpZGEPNQ7z9ZxFYntw
# 3            killiney-kopitiam-singapore-11  cb-E5IvWjrWEo-Qm2zxhwg
# 4            killiney-kopitiam-singapore-11  UK2DsID5q3MCqYX23S6xXw
# 0                   starbucks-singapore-129  Q1oMmm7tKPOzA7_gqcV4zg
# 1                   starbucks-singapore-129  41MtZiv6L0dB4S9NdnO6_g
# 2                   starbucks-singapore-129  37veRneM-BBpXzSNw-jCGw
# 3                   starbucks-singapore-129  Xij-B5G19fXDZ9uYGPZAqg
# 4                   starbucks-singapore-129  Cd8OdDB6wJxurtAgU-IgHA
# 5                   starbucks-singapore-129  yDcJsT-IhVMH6sO19V_nbg
# 0  the-coffee-bean-and-tea-leaf-singapore-9  5BlYeEeFjEvXR3hNENRDzg
# 0          second-storey-cafe-bar-singapore  H8mXfh5XgGCqmMLwVH7k5A
# 0                   starbucks-singapore-118  EB3xsU98loQHCm6Ub1bJIA
# 0               hg-106-coffeeshop-singapore  0QeJC2inz6P-OVzROU_LNw
# 0                   starbucks-singapore-106  e3fX7_qkoSm-6-yTdlwcXw
# 0             jin-wee-coffee-shop-singapore  jfJF7wNEYW53_h1mE21ztg
#
#                                             userinfo  rating        date  \
# 0  {'link': '/user_details?userid=EIwNqeBDMQ4Q6k0...       5    4/6/2018
# 1  {'link': '/user_details?userid=_I4S9ZWAoJ2PDip...       4  10/14/2017
# 2  {'link': '/user_details?userid=VxwCgpZGEPNQ7z9...       4   12/2/2016
# 3  {'link': '/user_details?userid=cb-E5IvWjrWEo-Q...       4   9/18/2016
# 4  {'link': '/user_details?userid=UK2DsID5q3MCqYX...       4   3/20/2015
# 0  {'link': '/user_details?userid=Q1oMmm7tKPOzA7_...       4   8/13/2014
# 1  {'link': '/user_details?userid=41MtZiv6L0dB4S9...       3   8/22/2013
# 2  {'link': '/user_details?userid=37veRneM-BBpXzS...       4   8/19/2012
# 3  {'link': '/user_details?userid=Xij-B5G19fXDZ9u...       4  11/28/2013
# 4  {'link': '/user_details?userid=Cd8OdDB6wJxurtA...       4   8/12/2012
# 5  {'link': '/user_details?userid=yDcJsT-IhVMH6sO...       3   8/19/2012
# 0  {'link': '/user_details?userid=5BlYeEeFjEvXR3h...       5   5/26/2018
# 0  {'link': '/user_details?userid=H8mXfh5XgGCqmML...       3    4/7/2016
# 0  {'link': '/user_details?userid=EB3xsU98loQHCm6...       4   6/20/2015
# 0  {'link': '/user_details?userid=0QeJC2inz6P-OVz...       5   3/10/2016
# 0  {'link': '/user_details?userid=e3fX7_qkoSm-6-y...       3  12/28/2018
# 0  {'link': '/user_details?userid=jfJF7wNEYW53_h1...       4   8/11/2012
#
#                                               photos      username language  \
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...       Hanh T.       en
# 1                                                 []      Ityng H.       en
# 2                                                 []    Nailesh J.       en
# 3  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...        Rob K.       en
# 4                                                 []   Patricia M.       en
# 0                                                 []    Carolyn L.       en
# 1                                                 []  Alexander L.       en
# 2                                                 []     Jeremy H.       en
# 3                                                 []     Pearly C.       en
# 4  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...          K R.       en
# 5                                                 []       Joey Q.       en
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...   Cristian F.       en
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...    Melissa Y.       en
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...     Roland S.       en
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...       Tram N.       en
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...    Riza H. C.       en
# 0  [{'src': 'https://s3-media0.fl.yelpcdn.com/bph...     Gracia O.       en
#
#                                                 text
# 0  We came here to try a traditional Singaporean ...
# 1  Delayed post. I visited this location back in ...
# 2  Excellent food and great value for money. They...
# 3  This is a great locals place. Great for breakf...
# 4  I have to admit we didn&amp;#39;t really know ...
# 0  I have heard this is the first Starbucks outle...
# 1  Hey do you like university students? If not, w...
# 2  The Starbucks at Liat Towers is one of my favo...
# 3  Because it&amp;#39;s thanksgiving i decided to...
# 4  This is probably one of my favorite Starbucks ...
# 5  The Starbucks at Liat Towers - or informally k...
# 0  I was looking for a place to do some work and ...
# 0  Located literally on a second storey of a shop...
# 0  Usual hangout whenever my wife is having her a...
# 0  My last lunch in Singapore was yesterday. I th...
# 0  Time : 15:42hrs ish.<br&gt;<br&gt;Starbucks Co...
# 0  One of the few old school coffee shops left al...

# %%
# all_data.to_csv('sg_UIRRD_{}-{}.csv'.format(START_IDX, END_IDX), index=False)
all_data.to_csv('sg_UIRRD_rescrape2_{}-{}.csv'.format(START_IDX, END_IDX), index=False)
